# %%
import random

# %%
a1 = []
a2 = []
a3 = []
a4 = []
a5 = []

# %%
for _ in range(1000):
    a1.append(random.randint(0,100))
    a2.append(random.randint(50,70))
    a3.append(random.randint(10,20))
    a4.append(random.randint(5,10))
    a5.append(random.randint(20,80))

# %%
df = {
    'grade' : a1,
    'weight' : a2,
    'friends' : a3,
    'cousins' : a4,
    'projects' : a5,
}

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       10      68       15       10        47
# 1       76      52       13        6        67
# 2       63      51       20        8        66
# 3       95      64       12        5        27
# 4       92      62       10        8        64
# ..     ...     ...      ...      ...       ...
# 995     51      67       11        7        26
# 996     10      60       10        5        80
# 997     45      53       10        7        32
# 998     57      69       20        7        52
# 999      3      60       10        6        73
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#              grade       weight      friends     cousins     projects
# count  1000.000000  1000.000000  1000.000000  1000.00000  1000.000000
# mean     49.780000    59.934000    15.143000     7.51900    49.166000
# std      29.400885     6.104827     3.189471     1.70662    17.763502
# min       0.000000    50.000000    10.000000     5.00000    20.000000
# 25%      24.000000    55.000000    12.000000     6.00000    34.000000
# 50%      49.000000    60.000000    15.000000     7.00000    49.000000
# 75%      75.000000    65.000000    18.000000     9.00000    65.000000
# max     100.000000    70.000000    20.000000    10.00000    80.000000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
df1['grade'].count
# Out:
# <bound method Series.count of 0      10
# 1      76
# 2      63
# 3      95
# 4      92
#        ..
# 995    51
# 996    10
# 997    45
# 998    57
# 999     3
# Name: grade, Length: 1000, dtype: int64>

# %%
friend15 = df1['friends'] > 15

# %%
df1[friend15]
# Out:
#      grade  weight  friends  cousins  projects
# 2       63      51       20        8        66
# 5       73      60       19        6        76
# 6       80      52       18        7        53
# 9       62      64       18        9        72
# 10      22      66       16        6        74
# ..     ...     ...      ...      ...       ...
# 980      2      65       16        5        66
# 981     23      55       16        9        68
# 982     47      69       18        5        66
# 992      3      60       19       10        54
# 998     57      69       20        7        52
#
# [470 rows x 5 columns]

# %%
grade50 = df1['grade'] > 50

# %%
df1[grade18]
# Out:
#      grade  weight  friends  cousins  projects
# 1       76      52       13        6        67
# 2       63      51       20        8        66
# 3       95      64       12        5        27
# 4       92      62       10        8        64
# 5       73      60       19        6        76
# ..     ...     ...      ...      ...       ...
# 991     70      68       14        8        48
# 993     31      68       12        9        58
# 995     51      67       11        7        26
# 997     45      53       10        7        32
# 998     57      69       20        7        52
#
# [799 rows x 5 columns]

# %%
grade75 = df1['grade'] > 75

# %%
df1[grade98]
# Out:
#      grade  weight  friends  cousins  projects
# 27      99      58       12       10        27
# 53      99      56       13        7        48
# 60      99      54       13        6        29
# 92     100      59       16       10        60
# 179     99      61       11        6        49
# 209     99      70       15        6        27
# 247    100      54       16        9        78
# 275    100      62       19        5        68
# 309     99      52       14        5        65
# 435    100      68       12       10        71
# 500    100      66       11       10        42
# 561     99      65       12        7        42
# 627     99      64       16        9        76
# 693     99      68       10       10        67
# 695     99      65       17        6        68
# 931     99      52       11       10        71

# %%
df1[friend15 & grade75]['friends']
# Out:
# 6      18
# 16     20
# 50     16
# 78     18
# 82     20
#        ..
# 888    19
# 933    16
# 950    20
# 974    16
# 977    20
# Name: friends, Length: 105, dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
df1[friend15 & grade75].plot()
# Out:
# <Axes: >

# %%
# %matplotlib inline

# %%
df1[friend15 & grade75].plot()
# Out:
# <Axes: >

# %%
df1[friend15 & grade75].plot(x= 'grade',y= 'projects',kind='bar', title='semple graph')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.legend('Test Data')
plt.show()

# %%
df1.to_csv('/Feb6TestData.csv')
